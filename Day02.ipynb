# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.0.3'

# %%
game=pd.read_csv("vgsalesGlobale.csv")

# %%
game
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
game.Genre.value_counts()
# Out:
# Genre
# Action          3316
# Sports          2346
# Misc            1739
# Role-Playing    1488
# Shooter         1310
# Adventure       1286
# Racing          1249
# Platform         886
# Simulation       867
# Fighting         848
# Strategy         681
# Puzzle           582
# Name: count, dtype: int64

# %%
game.Genre.value_counts(normalize=True)
# Out:
# Genre
# Action          0.199783
# Sports          0.141342
# Misc            0.104772
# Role-Playing    0.089649
# Shooter         0.078925
# Adventure       0.077479
# Racing          0.075250
# Platform        0.053380
# Simulation      0.052235
# Fighting        0.051090
# Strategy        0.041029
# Puzzle          0.035064
# Name: proportion, dtype: float64

# %%
import pandas as pd

# %%
data=pd.read_csv("data2.csv")

# %%
data
# Out:
#       Series_reference   Period  Data_value Suppressed STATUS   UNITS  \
# 0          BDCQ.SEA1AA  2011.06     80078.0        NaN      F  Number
# 1          BDCQ.SEA1AA  2011.09     78324.0        NaN      F  Number
# 2          BDCQ.SEA1AA  2011.12     85850.0        NaN      F  Number
# 3          BDCQ.SEA1AA  2012.03     90743.0        NaN      F  Number
# 4          BDCQ.SEA1AA  2012.06     81780.0        NaN      F  Number
# ...                ...      ...         ...        ...    ...     ...
# 22184    BDCQ.SEE3999A  2017.06         NaN          Y      C  Number
# 22185    BDCQ.SEE3999A  2017.09         NaN          Y      C  Number
# 22186    BDCQ.SEE3999A  2017.12         NaN          Y      C  Number
# 22187    BDCQ.SEE3999A  2018.03         NaN          Y      C  Number
# 22188    BDCQ.SEE3999A  2018.06         NaN          Y      C  Number
#
#        Magnitude                         Subject  \
# 0              0  Business Data Collection - BDC
# ...

# %%
data.shape
# Out:
# (22189, 14)

# %%
data.tail
# Out:
# <bound method NDFrame.tail of       Series_reference   Period  Data_value Suppressed STATUS   UNITS  \
# 0          BDCQ.SEA1AA  2011.06     80078.0        NaN      F  Number
# 1          BDCQ.SEA1AA  2011.09     78324.0        NaN      F  Number
# 2          BDCQ.SEA1AA  2011.12     85850.0        NaN      F  Number
# 3          BDCQ.SEA1AA  2012.03     90743.0        NaN      F  Number
# 4          BDCQ.SEA1AA  2012.06     81780.0        NaN      F  Number
# ...                ...      ...         ...        ...    ...     ...
# 22184    BDCQ.SEE3999A  2017.06         NaN          Y      C  Number
# 22185    BDCQ.SEE3999A  2017.09         NaN          Y      C  Number
# 22186    BDCQ.SEE3999A  2017.12         NaN          Y      C  Number
# 22187    BDCQ.SEE3999A  2018.03         NaN          Y      C  Number
# 22188    BDCQ.SEE3999A  2018.06         NaN          Y      C  Number
#
#        Magnitude                         Subject  \
# ...

# %%
data.Subject.value_counts()
# Out:
# Subject
# Business Data Collection - BDC    22189
# Name: count, dtype: int64

# %%
data.head()
# Out:
#   Series_reference   Period  Data_value Suppressed STATUS   UNITS  Magnitude  \
# 0      BDCQ.SEA1AA  2011.06     80078.0        NaN      F  Number          0
# 1      BDCQ.SEA1AA  2011.09     78324.0        NaN      F  Number          0
# 2      BDCQ.SEA1AA  2011.12     85850.0        NaN      F  Number          0
# 3      BDCQ.SEA1AA  2012.03     90743.0        NaN      F  Number          0
# 4      BDCQ.SEA1AA  2012.06     81780.0        NaN      F  Number          0
#
#                           Subject                            Group  \
# 0  Business Data Collection - BDC  Industry by employment variable
# 1  Business Data Collection - BDC  Industry by employment variable
# 2  Business Data Collection - BDC  Industry by employment variable
# 3  Business Data Collection - BDC  Industry by employment variable
# 4  Business Data Collection - BDC  Industry by employment variable
#
#   Series_title_1                     Series_title_2 Series_title_3  \
# ...

# %%
data.head(11)
# Out:
#    Series_reference   Period  Data_value Suppressed STATUS   UNITS  Magnitude  \
# 0       BDCQ.SEA1AA  2011.06     80078.0        NaN      F  Number          0
# 1       BDCQ.SEA1AA  2011.09     78324.0        NaN      F  Number          0
# 2       BDCQ.SEA1AA  2011.12     85850.0        NaN      F  Number          0
# 3       BDCQ.SEA1AA  2012.03     90743.0        NaN      F  Number          0
# 4       BDCQ.SEA1AA  2012.06     81780.0        NaN      F  Number          0
# 5       BDCQ.SEA1AA  2012.09     79261.0        NaN      F  Number          0
# 6       BDCQ.SEA1AA  2012.12     87793.0        NaN      F  Number          0
# 7       BDCQ.SEA1AA  2013.03     91571.0        NaN      F  Number          0
# 8       BDCQ.SEA1AA  2013.06     81687.0        NaN      F  Number          0
# 9       BDCQ.SEA1AA  2013.09     81471.0        NaN      F  Number          0
# 10      BDCQ.SEA1AA  2013.12     93950.0        NaN      F  Number          0
#
# ...

# %%
data.STATUS.describe()
# Out:
# count     22189
# unique        3
# top           F
# freq      12776
# Name: STATUS, dtype: object

# %%
data.Period.describe()
# Out:
# count    22189.000000
# mean      2016.896049
# std          3.557176
# min       2011.060000
# 25%       2014.060000
# 50%       2017.060000
# 75%       2020.060000
# max       2023.090000
# Name: Period, dtype: float64

# %%
data.Period.value_counts(normalize=True)
# Out:
# Period
# 2012.09    0.020821
# 2011.06    0.020731
# 2015.06    0.020731
# 2018.06    0.020731
# 2018.03    0.020731
# 2017.12    0.020731
# 2011.09    0.020731
# 2017.06    0.020731
# 2017.03    0.020731
# 2016.12    0.020731
# 2016.09    0.020731
# 2016.06    0.020731
# 2016.03    0.020731
# 2015.12    0.020731
# 2015.09    0.020731
# 2017.09    0.020731
# 2015.03    0.020731
# 2013.06    0.020731
# 2011.12    0.020731
# 2012.03    0.020731
# 2012.06    0.020731
# 2013.03    0.020731
# 2012.12    0.020731
# 2013.09    0.020731
# 2013.12    0.020731
# 2014.03    0.020731
# 2014.06    0.020731
# 2014.09    0.020731
# 2014.12    0.020731
# 2019.12    0.020686
# 2020.12    0.020686
# 2020.09    0.020686
# 2020.06    0.020686
# 2020.03    0.020686
# 2019.09    0.020686
# 2019.06    0.020686
# 2019.03    0.020686
# 2018.12    0.020686
# 2018.09    0.020686
# 2021.03    0.017441
# 2021.06    0.017441
# 2021.09    0.017441
# 2021.12    0.017441
# 2022.03    0.017441
# 2022.06    0.017441
# ...

# %%
data.Period.value_counts()
# Out:
# Period
# 2012.09    462
# 2011.06    460
# 2015.06    460
# 2018.06    460
# 2018.03    460
# 2017.12    460
# 2011.09    460
# 2017.06    460
# 2017.03    460
# 2016.12    460
# 2016.09    460
# 2016.06    460
# 2016.03    460
# 2015.12    460
# 2015.09    460
# 2017.09    460
# 2015.03    460
# 2013.06    460
# 2011.12    460
# 2012.03    460
# 2012.06    460
# 2013.03    460
# 2012.12    460
# 2013.09    460
# 2013.12    460
# 2014.03    460
# 2014.06    460
# 2014.09    460
# 2014.12    460
# 2019.12    459
# 2020.12    459
# 2020.09    459
# 2020.06    459
# 2020.03    459
# 2019.09    459
# 2019.06    459
# 2019.03    459
# 2018.12    459
# 2018.09    459
# 2021.03    387
# 2021.06    387
# 2021.09    387
# 2021.12    387
# 2022.03    387
# 2022.06    387
# 2022.09    387
# 2022.12    387
# 2023.03    387
# 2023.06    387
# 2023.09    387
# Name: count, dtype: int64

# %%
data
# Out:
#       Series_reference   Period  Data_value Suppressed STATUS   UNITS  \
# 0          BDCQ.SEA1AA  2011.06     80078.0        NaN      F  Number
# 1          BDCQ.SEA1AA  2011.09     78324.0        NaN      F  Number
# 2          BDCQ.SEA1AA  2011.12     85850.0        NaN      F  Number
# 3          BDCQ.SEA1AA  2012.03     90743.0        NaN      F  Number
# 4          BDCQ.SEA1AA  2012.06     81780.0        NaN      F  Number
# ...                ...      ...         ...        ...    ...     ...
# 22184    BDCQ.SEE3999A  2017.06         NaN          Y      C  Number
# 22185    BDCQ.SEE3999A  2017.09         NaN          Y      C  Number
# 22186    BDCQ.SEE3999A  2017.12         NaN          Y      C  Number
# 22187    BDCQ.SEE3999A  2018.03         NaN          Y      C  Number
# 22188    BDCQ.SEE3999A  2018.06         NaN          Y      C  Number
#
#        Magnitude                         Subject  \
# 0              0  Business Data Collection - BDC
# ...

# %%
data.Group.describe()
# Out:
# count                                            22189
# unique                                               5
# top       Territorial authority by employment variable
# freq                                             10081
# Name: Group, dtype: object

# %%
data.Group.value_counts()
# Out:
# Group
# Territorial authority by employment variable    10081
# Industry by employment variable                  5560
# Region by employment variable                    5248
# Age by employment variable                       1100
# Sex by employment variable                        200
# Name: count, dtype: int64

# %%
data.Group.value_counts(normalize=True)
# Out:
# Group
# Territorial authority by employment variable    0.454324
# Industry by employment variable                 0.250575
# Region by employment variable                   0.236514
# Age by employment variable                      0.049574
# Sex by employment variable                      0.009013
# Name: proportion, dtype: float64

# %%
data.Data_value.value_counts()
# Out:
# Data_value
# 21113.0     5
# 12459.0     5
# 5353.0      5
# 15895.0     4
# 6004.0      4
#            ..
# 77877.0     1
# 77776.0     1
# 78176.0     1
# 78509.0     1
# 829923.0    1
# Name: count, Length: 17342, dtype: int64

# %%
data.Data_value.value_counts(normalize=True)
# Out:
# Data_value
# 21113.0     0.000258
# 12459.0     0.000258
# 5353.0      0.000258
# 15895.0     0.000207
# 6004.0      0.000207
#               ...
# 77877.0     0.000052
# 77776.0     0.000052
# 78176.0     0.000052
# 78509.0     0.000052
# 829923.0    0.000052
# Name: proportion, Length: 17342, dtype: float64

# %%
game
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
pd.crosstab(game.Genre,game.Year)
# Out:
# Year          1980.0  1981.0  1982.0  1983.0  1984.0  1985.0  1986.0  1987.0  \
# Genre
# Action             1      25      18       7       1       2       6       2
# Adventure          0       0       0       1       0       0       0       1
# Fighting           1       0       0       0       0       1       0       2
# Misc               4       0       1       1       1       0       0       0
# Platform           0       3       5       5       1       4       6       2
# Puzzle             0       2       3       1       3       4       0       0
# Racing             0       1       2       0       3       0       1       0
# Role-Playing       0       0       0       0       0       0       1       3
# Shooter            2      10       5       1       3       1       4       2
# Simulation         0       1       0       0       0       1       0       0
# Sports             1       4       2       1       2       1       3       4
# ...

# %%
pd.crosstab(data.Subject,data.Period)
# Out:
# Period                          2011.06  2011.09  2011.12  2012.03  2012.06  \
# Subject
# Business Data Collection - BDC      460      460      460      460      460
#
# Period                          2012.09  2012.12  2013.03  2013.06  2013.09  \
# Subject
# Business Data Collection - BDC      462      460      460      460      460
#
# Period                          ...  2021.06  2021.09  2021.12  2022.03  \
# Subject                         ...
# Business Data Collection - BDC  ...      387      387      387      387
#
# Period                          2022.06  2022.09  2022.12  2023.03  2023.06  \
# Subject
# Business Data Collection - BDC      387      387      387      387      387
#
# Period                          2023.09
# Subject
# Business Data Collection - BDC      387
#
# [1 rows x 50 columns]

# %%
pd.crosstab(data.Group,data.Period)
# Out:
# Period                                        2011.06  2011.09  2011.12  \
# Group
# Age by employment variable                         22       22       22
# Industry by employment variable                   120      120      120
# Region by employment variable                     112      112      112
# Sex by employment variable                          4        4        4
# Territorial authority by employment variable      202      202      202
#
# Period                                        2012.03  2012.06  2012.09  \
# Group
# Age by employment variable                         22       22       22
# Industry by employment variable                   120      120      120
# Region by employment variable                     112      112      112
# Sex by employment variable                          4        4        4
# Territorial authority by employment variable      202      202      204
#
# Period                                        2012.12  2013.03  2013.06  \
# Group
# ...

# %%
g=pd.crosstab(data["Group"],data["Period"])
g.plot(kind="bar")
# Out:
# <Axes: xlabel='Group'>

# %%
# Out:
# Period                                        2011.06  2011.09  2011.12  \
# Group
# Age by employment variable                         22       22       22
# Industry by employment variable                   120      120      120
# Region by employment variable                     112      112      112
# Sex by employment variable                          4        4        4
# Territorial authority by employment variable      202      202      202
#
# Period                                        2012.03  2012.06  2012.09  \
# Group
# Age by employment variable                         22       22       22
# Industry by employment variable                   120      120      120
# Region by employment variable                     112      112      112
# Sex by employment variable                          4        4        4
# Territorial authority by employment variable      202      202      204
#
# Period                                        2012.12  2013.03  2013.06  \
# Group
# ...

# %%
g=pd.crosstab(data["Subject"],data["Period"])
g.plot(kind="bar",stacked=True)
# Out:
# <Axes: xlabel='Subject'>

# %%
df = pd.DataFrame({
    'gender': ['male', 'male', 'female', 'female', 'male', 'female', 'male', 'female'],
    'education_level': ['high school', 'college', 'college', 'graduate', 'high school', 'graduate', 'college', 'graduate'],
    'score': [75, 82, 88, 95, 69, 92, 78, 85]
})

# %%
df
# Out:
#    gender education_level  score
# 0    male     high school     75
# 1    male         college     82
# 2  female         college     88
# 3  female        graduate     95
# 4    male     high school     69
# 5  female        graduate     92
# 6    male         college     78
# 7  female        graduate     85

# %%
ct_viz = pd.crosstab(df['gender'], df['education_level'])
ct_viz.plot(kind='bar', stacked=True)
# Out:
# <Axes: xlabel='gender'>

# %%
ct_viz = pd.crosstab(df['gender'], df['education_level'])
ct_viz.plot(kind='hist', stacked=True)
# Out:
# <Axes: ylabel='Frequency'>

# %%
ct_viz = pd.crosstab(df['gender'], df['education_level'])
ct_viz.plot(kind='pie',subplots=True)
# Out:
# array([<Axes: ylabel='college'>, <Axes: ylabel='graduate'>,
#        <Axes: ylabel='high school'>], dtype=object)

# %%
df.loc[[0,1,2]]
# Out:
#    gender education_level  score
# 0    male     high school     75
# 1    male         college     82
# 2  female         college     88

# %%
df.loc[[2,3,5]]
# Out:
#    gender education_level  score
# 2  female         college     88
# 3  female        graduate     95
# 5  female        graduate     92

# %%
df.loc[[0,1,2,3],['gender']]
# Out:
#    gender
# 0    male
# 1    male
# 2  female
# 3  female

# %%
df.loc[[0,1,2,3],['gender','education_level']]
# Out:
#    gender education_level
# 0    male     high school
# 1    male         college
# 2  female         college
# 3  female        graduate

# %%
df.loc[:]
# Out:
#    gender education_level  score
# 0    male     high school     75
# 1    male         college     82
# 2  female         college     88
# 3  female        graduate     95
# 4    male     high school     69
# 5  female        graduate     92
# 6    male         college     78
# 7  female        graduate     85

# %%
df.loc[:,['gender']]
# Out:
#    gender
# 0    male
# 1    male
# 2  female
# 3  female
# 4    male
# 5  female
# 6    male
# 7  female

# %%
df.loc[[0,2,4,6],:]
# Out:
#    gender education_level  score
# 0    male     high school     75
# 2  female         college     88
# 4    male     high school     69
# 6    male         college     78

# %%
import pandas as pd

# %%
d={"name":["Bill","Tom","Tim","John","Alex","Vanessa","Kate"],      
      "score":[90,80,85,75,95,60,65],      
      "sport":["Wrestling","Football","Skiing","Swimming","Tennis",
               "Karete","Surfing"],      
      "gender":["M","M","M","M","F","F","F"]}

# %%
data = pd.DataFrame(d)
data.loc[:]
# Out:
#       name  score      sport gender
# 0     Bill     90  Wrestling      M
# 1      Tom     80   Football      M
# 2      Tim     85     Skiing      M
# 3     John     75   Swimming      M
# 4     Alex     95     Tennis      F
# 5  Vanessa     60     Karete      F
# 6     Kate     65    Surfing      F

# %%
data
# Out:
#       name  score      sport gender
# 0     Bill     90  Wrestling      M
# 1      Tom     80   Football      M
# 2      Tim     85     Skiing      M
# 3     John     75   Swimming      M
# 4     Alex     95     Tennis      F
# 5  Vanessa     60     Karete      F
# 6     Kate     65    Surfing      F

# %%
data["score"]>80
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# 5    False
# 6    False
# Name: score, dtype: bool

# %%
data.iloc[[0,1,2]]
# Out:
#    name  score      sport gender
# 0  Bill     90  Wrestling      M
# 1   Tom     80   Football      M
# 2   Tim     85     Skiing      M

# %%
data.iloc[[0,1,2],[0,1,2]]
# Out:
#    name  score      sport
# 0  Bill     90  Wrestling
# 1   Tom     80   Football
# 2   Tim     85     Skiing

# %%
data[['name','sport']]
# Out:
#       name      sport
# 0     Bill  Wrestling
# 1      Tom   Football
# 2      Tim     Skiing
# 3     John   Swimming
# 4     Alex     Tennis
# 5  Vanessa     Karete
# 6     Kate    Surfing

# %%
data.iloc[[2,4,6],[0,1]]
# Out:
#    name  score
# 2   Tim     85
# 4  Alex     95
# 6  Kate     65
